# %% [markdown]
# <a href="https://colab.research.google.com/github/asmit-ayank/UCS420/blob/main/Assignment%202/Assignment_2_UCS420.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q 1. Create a List L that is defined as= [10, 20, 30, 40, 50, 60, 70, 80].
#
#
# 1.   WAP to add 200 and 300 to L.
# 2.   WAP to remove 10 and 30 from L.
# 3.   WAP to sort L in ascending order.
# 4.   WAP to sort L in descending order.

# %%
L=[10,20,30,40,50,60,70,80]
L.append(200)
L.append(300)
print("List after adding 200 and 300", L)
L.remove(10)
L.remove(30)
print("List removing 10 and 30", L)
L.sort()
print("List in ascending order", L)
L.sort(reverse=True)
print("List in descending order", L)
# Out:
# List after adding 200 and 300 [10, 20, 30, 40, 50, 60, 70, 80, 200, 300]
# List removing 10 and 30 [20, 40, 50, 60, 70, 80, 200, 300]
# List in ascending order [20, 40, 50, 60, 70, 80, 200, 300]
# List in descending order [300, 200, 80, 70, 60, 50, 40, 20]

# %% [markdown]
# Q 2. Create a tuple of marks scored as scores = (45, 89.5, 76, 45.4, 89, 92, 58, 45) and perform the following operations using tuple functions:
#
#
#
# 1.   Identify the highest score and its index in the tuple.
# 2.   LFind the lowest score and count how many times it appears.
# 3.   Reverse the tuple and return it as a list.
# 4.   Check if a specific score ‘76’ (input by the user) is present in the tuple and print its first occurrence index, or a message saying it’s not present.

# %%
scores = (45, 89.5, 76, 45.4, 89, 92, 58, 45)
highest_score = max(scores)
highest_index = scores.index(highest_score)
print(f"Highest score: {highest_score}, Index: {highest_index}")
lowest_score = min(scores)
lowest_count = scores.count(lowest_score)
print(f"Lowest score: {lowest_score}, Count: {lowest_count}")
reversed_list = list(reversed(scores))
print(f"Reversed tuple as list: {reversed_list}")
specific_score = int(input("Enter a score to check (e.g., 76): "))
if specific_score in scores:
    first_index = scores.index(specific_score)
    print(f"The score {specific_score} is present at index {first_index}.")
else:
    print(f"The score {specific_score} is not present in the tuple.")
# Out:
# Highest score: 92, Index: 5
# Lowest score: 45, Count: 2
# Reversed tuple as list: [45, 58, 92, 89, 45.4, 76, 89.5, 45]
# Enter a score to check (e.g., 76): 85
# The score 85 is not present in the tuple.

# %% [markdown]
# Q. 3 WAP to create a list of 100 random numbers between 100 and 900. Count and print the:
#
# i. All odd numbers
#
# ii. All even numbers
#
# iii. All prime numbers

# %%
import random
numbers = [random.randint(100, 900) for _ in range(100)]
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True
odd_numbers = [num for num in numbers if num % 2 != 0]
print(f"Odd Numbers ({len(odd_numbers)}): {odd_numbers}")
even_numbers = [num for num in numbers if num % 2 == 0]
print(f"Even Numbers ({len(even_numbers)}): {even_numbers}")
prime_numbers = [num for num in numbers if is_prime(num)]
print(f"Prime Numbers ({len(prime_numbers)}): {prime_numbers}")
# Out:
# Odd Numbers (45): [565, 575, 403, 567, 681, 399, 669, 629, 109, 549, 325, 305, 777, 111, 183, 251, 861, 393, 665, 203, 291, 165, 563, 789, 409, 527, 435, 409, 731, 725, 361, 719, 537, 411, 599, 137, 277, 419, 711, 617, 447, 203, 303, 669, 139]
# Even Numbers (55): [310, 314, 332, 560, 106, 232, 512, 620, 342, 720, 356, 834, 736, 590, 130, 810, 452, 874, 424, 632, 428, 572, 298, 102, 322, 514, 204, 114, 508, 336, 690, 246, 594, 750, 412, 196, 672, 282, 854, 110, 810, 130, 402, 198, 756, 298, 644, 796, 420, 232, 788, 162, 188, 334, 766]
# Prime Numbers (12): [109, 251, 563, 409, 409, 719, 599, 137, 277, 419, 617, 139]

# %% [markdown]
# Consider the following two sets, A and B, represenƟng scores of two teams in mulƟple
# matches. A = {34, 56, 78, 90} and B = {78, 45, 90, 23}
# WAP to perform the following operaƟons using set funcƟons:
#
# i. Find the unique scores achieved by both teams (union of sets).
#
# ii. IdenƟfy the scores that are common to both teams (intersecƟon of sets).
#
# iii. Find the scores that are exclusive to each team (symmetric difference).
#
# iv. Check if the scores of team A are a subset of team B, and if team B's scores are
# a superset of team A.
#
# v. Remove a specific score X (input by the user) from set A if it exists. If not, print
# a message saying it is not present.

# %%
A = {34, 56, 78, 90}
B = {78, 45, 90, 23}
union_scores = A.union(B)
print(f"Union of A and B (Unique scores): {union_scores}")
common_scores = A.intersection(B)
print(f"Intersection of A and B (Common scores): {common_scores}")
exclusive_scores = A.symmetric_difference(B)
print(f"Symmetric Difference (Exclusive scores): {exclusive_scores}")
is_subset = A.issubset(B)
is_superset = B.issuperset(A)
print(f"Is A a subset of B? {is_subset}")
print(f"Is B a superset of A? {is_superset}")
X = int(input("Enter a score to remove from set A: "))
if X in A:
    A.remove(X)
    print(f"Score {X} removed from set A. Updated A: {A}")
else:
    print(f"Score {X} is not present in set A.")
# Out:
# Union of A and B (Unique scores): {34, 45, 78, 23, 56, 90}
# Intersection of A and B (Common scores): {90, 78}
# Symmetric Difference (Exclusive scores): {34, 45, 23, 56}
# Is A a subset of B? False
# Is B a superset of A? False
# Enter a score to remove from set A: 56
# Score 56 removed from set A. Updated A: {34, 90, 78}

# %% [markdown]
# 5. Write a program to rename a key city to a locaƟon in the following dicƟonary.
#
# ![image.png](data:image/png;base64,...)

# %%
sample_dict = {
    "name": "Kelly",
    "age": 25,
    "salary": 8000,
    "city": "New york"
}

sample_dict["location"] = sample_dict.pop("city")

print(sample_dict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}
