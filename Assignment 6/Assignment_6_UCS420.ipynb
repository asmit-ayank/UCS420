# %% [markdown]
# <a href="https://colab.research.google.com/github/asmit-ayank/UCS420/blob/main/Assignment%206/Assignment_6_UCS420.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Ask the user to enter a value (e.g., M) for a mathematical function.
#
#
# *   Generate x values from -10 to 10 using np.linspace().
# *   Compute y values for:
#
#    *   y= M⋅x^2
#    *   y=M⋅sin(x)
#
#
# *   Plot both functions in a single figure:
#
#    *   Use different colors and line styles.
#    *   Add legend, grid, and title.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

val = float(input("Enter a value: "))

t_vals = np.linspace(-10, 10, 400)

res1 = val * t_vals**2
res2 = val * np.sin(t_vals)

plt.figure(figsize=(8, 6))
plt.plot(t_vals, res1, 'r-', label='y = val * x^2')
plt.plot(t_vals, res2, 'b--', label='y = val * sin(x)')

plt.legend()
plt.grid(True)
plt.title("Plot of y = val*x^2 and y = val*sin(x)")

plt.show()
# Out:
# Enter a value: 10

# %% [markdown]
# Q.2 Create a dataset of five subjects and scores.
#
#
# *   Convert it into a Pandas DataFrame.
# *   Plot the scores using a Seaborn bar plot with:
#
#   *   Different colors for each bar.
#   *   Annotations on top of each bar.
#   *   Title, axis labels, and grid.

# %%
import matplotlib.pyplot as plt

info = {'Topic': ['Math', 'Science', 'English', 'History', 'Art'],
        'Marks': [85, 56, 92, 90, 88]}

data = pd.DataFrame(info)

plt.figure(figsize=(8, 6))
plot = sns.barplot(x='Topic', y='Marks', data=data, palette='viridis')

for idx, val in enumerate(data['Marks']):
    plt.text(idx, val + 1, str(val), ha='center', fontsize=12)

plt.title("Scores in Various Subjects")
plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.grid(True, axis='y')

plt.show()
# Out:
# <ipython-input-3-89a52d2fa916>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x='Topic', y='Marks', data=data, palette='viridis')

# %% [markdown]
# Q3. Write a Python script to select your roll number as seed for NumPy and
# then generate a dataset of 50 values using np.random.randn().
# *   Create a 2x2 subplot layout displaying:
#   *   Line plot showing cumulative sum.
#   *   Scatter plot with random noise.
# *   Customize with titles, axis labels, and grids.

# %%
seed_val = 102497002
np.random.seed(seed_val)

data_vals = np.random.randn(50)
cumulative_vals = np.cumsum(data_vals)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].plot(cumulative_vals, 'g-', linewidth=2)
axes[0].set_title("Cumulative Sum Plot")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Cumulative Sum")
axes[0].grid(True)

axes[1].scatter(range(50), data_vals, c='r', marker='o')
axes[1].set_title("Scatter Plot with Random Noise")
axes[1].set_xlabel("Index")
axes[1].set_ylabel("Value")
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Q.4 Download Data-set from the below link
# https://github.com/AnjulaMehto/MCA/blob/main/company_sales_data.csv
# Apply ‘seaborn’ library to do the following.
# 1. Read Total profit of all months and show it using a line plot.
# 2. Read all product sales data and show it using a multiline plot.
# 3. Plot bar chart for all the features/attributes.

# %%
url = "https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv"
df = pd.read_csv(url)


plt.figure(figsize=(8, 5))
sns.lineplot(x=df["month_number"], y=df["total_profit"], marker="o", label="Total Profit", color="blue")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("1) Total Profit Per Month")
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(8,5))
for column in df.columns[1:-1]:
    sns.lineplot(x=df["month_number"], y=df[column], marker="o", label=column)
plt.xlabel("Month Number")
plt.ylabel("Sales")
plt.title("2) Sales of Different Products Per Month")
plt.legend()
plt.grid(True)
plt.show()


df.set_index("month_number").plot(kind="bar", figsize=(10, 6))
plt.xlabel("Month Number")
plt.ylabel("Values")
plt.title("3) Bar Chart of All Features")
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid(axis="y", linestyle="--")
plt.show()
